# %% [markdown]
# # Quick Analysis

# %%
% matplotlib inline

import os

import matplotlib.pyplot as plt
import numpy as np

from lammps import LammpsRun

# %%
temperatures = np.linspace(1e-3, 4000.0, 400)

# %%
temp_directory = os.path.join('runs/thermal_expansion_test1', '{:.3f}'.format(300.000))
lammps_run = LammpsRun(
        os.path.join(temp_directory, 'in.data'),
        lammps_log=os.path.join(temp_directory, 'lammps.log'),
        lammps_dump=os.path.join(temp_directory, 'mol.lammpstrj')
    )

# %%
# lammps_run.final_structure

# %%
lammps_run.lammps_log.thermo_data.dtype.names
# Out:
# ('step',
#  'vol',
#  'temp',
#  'press',
#  'ke',
#  'pe',
#  'etotal',
#  'enthalpy',
#  'evdwl',
#  'ecoul',
#  'epair',
#  'ebond',
#  'eangle',
#  'edihed',
#  'eimp',
#  'emol',
#  'elong',
#  'etail',
#  'lx',
#  'ly',
#  'lz',
#  'xy',
#  'xz',
#  'yz',
#  'pxy',
#  'pxz',
#  'pyz',
#  'pxx',
#  'pyy',
#  'pzz',
#  'density')

# %%
plt.plot(lammps_run.lammps_log.thermo_data['temp'])

# %%
plt.plot(lammps_run.lammps_log.thermo_data['etotal'])

# %%
plt.plot(lammps_run.lammps_log.thermo_data['vol'])

# %%
plt.plot(lammps_run.lammps_log.thermo_data['press'])

# %%
plt.plot(lammps_run.lammps_log.thermo_data['ke'])

# %%
plt.plot(lammps_run.lammps_log.thermo_data['pe'])
